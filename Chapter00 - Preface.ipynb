# %%
from IPython.display import Image
Image(filename='images\\sasvspython.PNG')

# %% [markdown]
# <p>Since 1993 I start learning SAS software not just use as a tool but SAS was my career. Started as a technical support, then system analyst and leading the tech team and ultimately being a technical salesperson who sold +90 million software and services to top banks, telecommunications, governments &amp; etc. I was privileged to work with all top tier firms in order to understand why / how they use SAS and what make the software unique in order to value add to solve business problem by analytics.</p>
